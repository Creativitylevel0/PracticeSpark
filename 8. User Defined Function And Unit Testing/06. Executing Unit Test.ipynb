# %% [markdown]
# ####1. Run Unit Test

# %% [markdown]
# 1.1 Reload during development

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# 1.2 Run Unit Test

# %%
import pytest
import sys

sys.dont_write_bytecode = True

retcode = pytest.main([".", "-v", "-p", "no:cacheprovider"]) # Run pytest with the current directory as the root directory
assert retcode == 0, "The pytest invocation failed."
